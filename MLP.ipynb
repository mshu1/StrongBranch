# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import src.graph_ops as go
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.autograd import Variable
from torch.utils import data
from sklearn.preprocessing import OneHotEncoder

# %%
graphs = np.load("data/graph_10node7500.npy")
# options: graph_10+20k, graph_10+10k
labels = np.load("data/labels_10node7500.npy")
# options: labels_10+20k, labels_10+10k
X = go.compress_graphs(graphs)

# %%
y = pd.DataFrame(np.zeros((labels.shape[0], 10)))
y = y.add(pd.get_dummies(labels[:,0]), fill_value=0)
y = y.add(pd.get_dummies(labels[:,1]), fill_value=0)
y = y.values.astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
def cross_entropy(input, target, size_average=True):
    return torch.mean(-target * torch.log(input))


class MLP(nn.Module): 
    
    #constructor
    #take in X as a parameter
    def __init__(self, X, y, weight_decay = 0.0005):
        super(MLP, self).__init__()
        
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        #self.device = 'cpu'
        
        y_dim = y.shape[-1]
        X_dim = X.shape[-1]
        
        
        
        self.fc1 = nn.Linear(X_dim, 50)
        self.fc2 = nn.Linear(50, 50)
        self.fc3 = nn.Linear(50, 50)
        self.fc4 = nn.Linear(50, 50)
        self.fc5 = nn.Linear(50, 50)
        self.fc6 = nn.Linear(50, y_dim)
        self.sigmoid = nn.Sigmoid()

        
        self.optimizer = torch.optim.Adam(self.parameters(), lr=0.001, weight_decay = weight_decay)
        self.to(self.device)
        
    # 1. input X
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.fc6(x)
        x = self.sigmoid(x)
        x = 2*x/(x.sum(1)[:,None])
        return x
    
    def loss(self, pred, true):
        #PyTorch's own cross entropy loss function.
        score = cross_entropy
        l = None
        for i in range(true.shape[1]):
            if l is None:
                l = score(pred[:,i], true[:,i])
            else:
                l += score(pred[:,i], true[:,i])
        return l
    

    def fit(self, X, y, early_stopping = True, patience = 50):
        
        if isinstance(X, pd.DataFrame):
            X_arr = X.values
            X_tens = Variable(torch.Tensor(X_arr).float())
        else:
            X_tens = Variable(torch.Tensor(X).float())
        if isinstance(y, pd.DataFrame) or isinstance(y, pd.Series):
            y_arr = y.values
            if len(y_arr.shape) == 1:
                y_arr = y_arr[:,None]
            y_tens = Variable(torch.Tensor(y_arr).float())
        else:
            if len(y.shape) == 1:
                y = y[:,None]
            y_tens = Variable(torch.Tensor(y).float())
        
        X_tens = X_tens.to(self.device)
        y_tens = y_tens.to(self.device)
        
        if early_stopping == True:
            
            inds = np.arange(len(X_tens))
            num_train = int(len(X_tens) * .9)
            train_inds = np.random.choice(inds, num_train, replace=False)
            val_inds = np.setdiff1d(inds, train_inds)
            X_train = X_tens[train_inds]
            y_train = y_tens[train_inds]
            X_val = X_tens[val_inds]
            y_val = y_tens[val_inds]
            
        for epoch in range(1000):
            self.optimizer.zero_grad()
            if early_stopping==True:
                out_train = self.forward(X_train)
                loss = self.loss(out_train, y_train)
            if early_stopping==False:
                out_train = self.forward(X_tens)
                loss = self.loss(out_train, y_tens)
                print(loss)
                loss.backward()
                self.optimizer.step()
                continue
                
            out_val = self.forward(X_val)
            loss_val = self.loss(out_val, y_val)
            print(loss_val)


            if epoch == 0:
                min_loss = loss_val
                best_weights = self.state_dict()
                counter = 0
            else:
                if loss_val < min_loss:
                    min_loss = loss_val
                    best_weights = self.state_dict()
                    counter = 0
                else:
                    counter += 1
                    if counter == patience:
                        self.load_state_dict(best_weights)
                        return
                
            loss.backward()
            self.optimizer.step()
    
    def predict_proba(self, X):
        if isinstance(X, pd.DataFrame):
            X_arr = X.values
            X_tens = Variable(torch.Tensor(X_arr).float())
        else:
            X_tens = Variable(torch.Tensor(X).float())
            
        X_tens = X_tens.to(self.device)
        
        predict_out = self.forward(X_tens)
        temp =  predict_out.cpu().detach().numpy()
        temp[temp > 1-1e-6] = 1-1e-6
        temp[temp < 1e-6]=1e-6
        return temp
    
    def predict(self, X):
        proba = self.predict_proba(X).argsort(1)[:,-2:]
        proba.sort(1)
        return proba
    
    def score(self, X, y):
        y_pred = self.predict(X)
        y_true = y.argsort(1)[:,-2:]
        y_true.sort(1)
        return (y_pred == y_true).all(1).mean().item()
    
    def top_k_acc(self, X,y, k = 5):
        """Get top k accuracy for prediction. I.e., were the 2 correct nodes 
        in the top k returned. Note, k=2 is the score function."""
        y_pred = self.predict_proba(X)
        y_true = y.argsort(1)[:,-2:]  
        y_true.sort(1)
        eqs_list = []
        top_k = y_pred.argsort(1)[:,-k:]
        for i in range(y_true.shape[0]):
            row = y_true[i]
            eqs_arr = []
            for ele in row:
                eqs_arr.append(np.any(ele == top_k[i]))
            eqs_arr = np.array(eqs_arr)
            eq = eqs_arr.all()
            eqs_list.append(eq)
        eqs = np.array(eqs_list)

        return eqs.mean()

# %%
mlp = MLP(X, y)

# %%
mlp.fit(X_train,y_train)
# Out:
# tensor(3.1996, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3.1914, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3.1827, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3.1735, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3.1640, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3.1539, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3.1430, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3.1310, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3.1175, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3.1026, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3.0859, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3.0675, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3.0472, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3.0250, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3.0010, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.9752, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.9478, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.9188, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.8884, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.8570, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.8251, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.7931, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.7615, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.7310, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.7021, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.6759, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.6528, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.6338, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.6189, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.6068, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.5957, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.5839, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.5702, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.5545, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.5372, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.5193, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.5015, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.4848, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.4697, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.4566, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.4453, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.4351, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.4257, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.4168, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.4081, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3991, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3901, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3809, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3713, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3614, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3518, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3424, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3339, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3266, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3208, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3165, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3136, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3115, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3099, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3084, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3069, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3052, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3033, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.3012, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2990, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2967, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2941, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2913, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2882, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2850, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2818, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2785, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2751, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2716, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2680, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2643, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2604, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2565, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2524, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2482, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2438, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2392, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2345, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2295, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2244, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2192, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2139, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2085, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.2030, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.1973, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.1915, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.1856, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.1792, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.1726, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.1656, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.1585, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.1510, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.1434, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.1355, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.1274, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.1192, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.1107, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.1021, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.0935, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.0850, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.0765, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.0681, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.0597, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.0515, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.0436, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.0361, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.0289, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.0219, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.0149, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.0081, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(2.0015, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9950, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9885, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9819, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9754, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9689, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9626, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9560, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9495, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9431, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9366, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9299, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9231, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9163, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9093, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.9022, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8951, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8878, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8806, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8736, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8664, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8596, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8526, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8462, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8399, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8348, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8290, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8242, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8185, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8137, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8096, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8050, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.8006, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7959, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7918, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7879, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7833, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7788, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7743, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7699, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7657, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7608, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7559, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7508, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7456, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7402, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7342, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7281, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7215, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7148, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7079, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.7005, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.6931, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.6851, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.6772, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.6686, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.6599, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.6508, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.6414, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.6315, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.6211, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.6104, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5993, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5883, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5768, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5668, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5535, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5404, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5275, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5156, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5039, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4900, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4778, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4669, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4540, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4423, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4322, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4207, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4102, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4004, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.3904, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.3818, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.3719, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.3637, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.3565, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.3475, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.3442, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.3340, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.3305, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.3210, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.3148, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.3121, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.3036, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.3028, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2927, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2892, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2856, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2788, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2798, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2703, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2703, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2634, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2589, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2594, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2508, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2508, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2451, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2412, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2384, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2339, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2331, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2266, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2269, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2202, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2182, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2155, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2110, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2095, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2045, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2043, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1973, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2012, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1903, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1930, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1841, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1807, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1796, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1730, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1741, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1665, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1637, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1593, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1556, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1545, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1478, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1467, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1401, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1388, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1338, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1301, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1271, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1213, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1209, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1135, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1154, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1066, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1058, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0997, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0963, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0946, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0885, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0894, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0813, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0820, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0739, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0720, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0684, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0643, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0648, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0612, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0648, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0613, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0500, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0525, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0449, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0424, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0448, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0338, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0327, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0361, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0249, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0227, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0272, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0178, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0148, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0176, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0100, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0083, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0104, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0029, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0002, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.0026, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.9968, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.9938, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.9958, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.9886, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.