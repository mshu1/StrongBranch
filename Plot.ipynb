# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
rand = [0.021906532129580457,
 0.06585236325013277,
 0.13688263409453,
 0.22530536378120022,
 0.32886351566648964,
 0.46999468932554433,
 0.6259957514604355,
 0.799522039298991,
 1.0]

# %%
mlp = [0.8927243759957515,
 0.9330855018587361,
 0.951141795007966,
 0.966542750929368,
 0.9798194370685077,
 0.9856611789697292,
 0.9915029208709506,
 0.9962825278810409,
 1.0]

# %%
lstm = [0.2703133297928837,
 0.4471587891662241,
 0.6064790228359002,
 0.7195963887413701,
 0.8066914498141264,
 0.8709506107275624,
 0.9182156133828996,
 0.9559214020180563,
 1.0]

# %%
cnn =[0.9139670738183749,
 0.9373340414232607,
 0.9564524694636218,
 0.966542750929368,
 0.9750398300584174,
 0.9835369091874668,
 0.9904407859798194,
 0.9941582580987786,
 1.0]

# %%
ax = plt.figure().gca()

plt.plot(np.arange(2,11), rand, label = 'Random')
plt.plot(np.arange(2,11), mlp, label = 'MLP')
plt.plot(np.arange(2,11), lstm, label = 'LSTM')
plt.plot(np.arange(2,11), cnn, label = 'CNN')
plt.legend()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
plt.title('Top K Accuracy')
plt.xlabel('K')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')
